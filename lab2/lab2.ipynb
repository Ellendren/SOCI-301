# %% [markdown]
# # Lab Assignment 2: Independent-Samples t Test
# ---
# Learning Outcomes:
# 1. Learn how to conduct independent-samples t-test,
# 2. Interpret the statistical results, and
# 3. Critically analyze real-world data and develop quantitative reasoning skills (UD Area B).
# ---
# ### Open states.sav and intialize data frame. Get dependencies
# ---

# %%
# load dependencies 
from IPython.display import display
import pandas as pd

# opens state
states_df = pd.read_spss("./States.sav")
display(states_df)
# Out:
#             State  Hom95  Hom10  Rape10  Robb10  Asslt10  Burg10  Larc10  \
# 0         Alabama   11.2    5.7    28.2    99.6    244.2   879.4  2415.6
# 1          Alaska    9.1    4.4    75.0    83.6    475.8   437.2  2187.3
# 2         Arizona   10.4    6.4    33.9   108.5    259.3   794.3  2403.2
# 3        Arkansas   10.4    4.7    45.0    81.3    374.3  1114.9  2253.8
# 4      California   11.2    4.9    22.4   156.0    257.4   614.3  1612.1
# 5        Colorado    5.8    2.4    43.7    62.3    212.4   520.0  1940.5
# 6     Connecticut    4.6    3.6    16.3    99.4    162.0   424.5  1581.0
# 7        Delaware    3.5    5.3    34.7   203.7    377.1   836.9  2396.5
# 8         Florida    7.3    5.2    28.6   138.7    369.8   899.5  2438.5
# 9         Georgia    9.5    5.8    21.6   127.7    248.2   998.4  2329.3
# 10         Hawaii    4.7    1.8    26.8    77.5    156.7   636.8  2302.4
# 11          Idaho    4.1    1.3    33.5    13.7    172.6   414.8  1496.7
# ...
