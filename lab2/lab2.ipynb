# %% [markdown]
# # Lab Assignment 2: Independent-Samples t Test
# ---
# Learning Outcomes:
# 1. Learn how to conduct independent-samples t-test,
# 2. Interpret the statistical results, and
# 3. Critically analyze real-world data and develop quantitative reasoning skills (UD Area B).
# ---
# ### Open states.sav and intialize data frame. Get dependencies
# ---

# %%
# load dependencies 
from IPython.display import display
import pandas as pd

# opens state
states_df = pd.read_spss("./GSS2016.sav")
display(states_df)
# Out:
#      ABANY ABDEFECT ABHLTH ABNOMORE ABPOOR ABRAPE ABSINGLE ADULTS  \
# 0      YES      YES    YES      YES    YES    YES      YES    2.0
# 1      NaN      NaN    NaN      NaN    NaN    NaN      NaN    1.0
# 2       NO       NO    YES       NO     NO    YES       NO    2.0
# 3       NO       NO    YES       NO     NO    YES       NO    4.0
# 4      YES      YES    YES      YES    YES    YES      YES    3.0
# ...    ...      ...    ...      ...    ...    ...      ...    ...
# 2862   NaN      NaN    NaN      NaN    NaN    NaN      NaN    2.0
# 2863    NO      YES    YES       NO     NO    YES       NO    1.0
# 2864   NaN      NaN    NaN      NaN    NaN    NaN      NaN    2.0
# 2865    NO       NO    YES       NO     NO     NO       NO    2.0
# 2866   NaN      YES    YES      NaN    NaN    YES      NaN    2.0
#
#             ADVFRONT   AGE  ...           WRKSTAT           WRKWAYUP WWWHR  \
# 0     Strongly agree  47.0  ...  WORKING FULLTIME  DISAGREE SOMEWHAT  15.0
# ...

# %% [markdown]
# ## Questions
# 1. Is there a relationship between parenthood (whether one has a child or not) and supportiveness of working mothers? Use variables PARENT and FECHLD in the analysis.
#
# &nbsp;&nbsp;&nbsp;&nbsp;a. State the null (H0) and alternative hypothesis (H1) based on the research question above. (2 pts)
#
# &nbsp;&nbsp;&nbsp;&nbsp;Answer:
#
# &nbsp;&nbsp;&nbsp;&nbsp;H<sub>0</sub>: There is no significant difference between parenthood and supportiveness of working mothers.
#
# &nbsp;&nbsp;&nbsp;&nbsp;H<sub>1</sub>: There is a significant difference between parenthood and supportiveness of working mothers.
#
# &nbsp;&nbsp;&nbsp;&nbsp;b. Test the hypotheses using independent samples t-test. Report the appropriate statistics in the table below (equal variance assumed). (2 pts)  Attach the tables produced. (2 pts)

# %%
# extract the needed varibles from the dataset
PARENT_FECHLD =
