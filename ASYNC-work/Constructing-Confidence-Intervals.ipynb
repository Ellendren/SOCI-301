# %%
# load dependencies 
from IPython.display import display
import pandas as pd
import scipy.stats as st 

# opens GSS2016
GSS16_df = pd.read_spss("./GSS2016.sav")
display(GSS16_df)
# Out:
#      ABANY ABDEFECT ABHLTH ABNOMORE ABPOOR ABRAPE ABSINGLE ADULTS  \
# 0      YES      YES    YES      YES    YES    YES      YES    2.0
# 1      NaN      NaN    NaN      NaN    NaN    NaN      NaN    1.0
# 2       NO       NO    YES       NO     NO    YES       NO    2.0
# 3       NO       NO    YES       NO     NO    YES       NO    4.0
# 4      YES      YES    YES      YES    YES    YES      YES    3.0
# ...    ...      ...    ...      ...    ...    ...      ...    ...
# 2862   NaN      NaN    NaN      NaN    NaN    NaN      NaN    2.0
# 2863    NO      YES    YES       NO     NO    YES       NO    1.0
# 2864   NaN      NaN    NaN      NaN    NaN    NaN      NaN    2.0
# 2865    NO       NO    YES       NO     NO     NO       NO    2.0
# 2866   NaN      YES    YES      NaN    NaN    YES      NaN    2.0
#
#             ADVFRONT   AGE  ...           WRKSTAT           WRKWAYUP WWWHR  \
# 0     Strongly agree  47.0  ...  WORKING FULLTIME  DISAGREE SOMEWHAT  15.0
# ...

# %% [markdown]
# ### Find the CHILDS variable and compute the descriptive statistics
# ---

# %%
st.t.interval(0.95, df=GSS16_df.CHILDS.size, loc=GSS)

# %%
GSS16_df.CHILDS
# Out:
# 0       3.0
# 1       0.0
# 2       2.0
# 3       4.0
# 4       2.0
#        ...
# 2862    2.0
# 2863    4.0
# 2864    4.0
# 2865    2.0
# 2866    2.0
# Name: CHILDS, Length: 2867, dtype: category
# Categories (9, object): [0.0, 1.0, 2.0, 3.0, ..., 5.0, 6.0, 7.0, 'EIGHT OR MORE']
